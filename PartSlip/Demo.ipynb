# %%
import sys
sys.path.insert(0,'../GroundingDINO')
sys.path.insert(0,'../SAM')
import os
import torch
import json
from pytorch3d.io import IO
import numpy as np
from src.utils import normalize_pc,save_colored_pc
from src.render_pc import render_pc
from src.gen_superpoint import gen_superpoint
from groundingdino.util.inference import load_model, load_image, predict, annotate
import cv2
from torchvision.ops import nms
import json
from segment_anything import sam_model_registry, SamPredictor
import matplotlib.pyplot as plt

# %%
def yolobbox2bbox(yolobox):
    x = yolobox[:,0]
    y = yolobox[:,1]
    w = yolobox[:,2]
    h = yolobox[:,3]
    xyxy = np.zeros_like(yolobox)
    xyxy[:,0] = x-w/2
    xyxy[:,1] = y-h/2
    xyxy[:,2] = x+w/2
    xyxy[:,3] = y+h/2
    return xyxy

# %%
def InferDINO(input_pc_file, category, part_names, zero_shot=False, save_dir="tmp"):
    if zero_shot:
        config ="GLIP/configs/glip_Swin_L.yaml"
        weight_path = "models/glip_large_model.pth"
        print("-----Zero-shot inference of %s-----" % input_pc_file)
    else:
        config ="GLIP/configs/glip_Swin_L_pt.yaml"
        weight_path = "models/%s.pth" % category
        print("-----Few-shot inference of %s-----" % input_pc_file)
        
    print("[loading GLIP model...]")
    model = load_model("../GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py", "../GroundingDINO/weights/groundingdino_swint_ogc.pth")

    print("[creating tmp dir...]")
    if torch.cuda.is_available():
        device = torch.device("cuda:0")
        torch.cuda.set_device(device)
    else:
        device = torch.device("cpu")
    io = IO()
    os.makedirs(save_dir, exist_ok=True)
    
    print("[normalizing input point cloud...]")
    xyz, rgb = normalize_pc(input_pc_file, save_dir, io, device)
    
    print("[rendering input point cloud...]")
    img_dir, pc_idx, screen_coords = render_pc(xyz, rgb, save_dir, device)
    TEXT_PROMPT = "chair . person . dog ."
    BOX_TRESHOLD = 0.35
    TEXT_TRESHOLD = 0.25
    
    preds = []
    for i in range(10):
        image_source, image = load_image(img_dir+f"/{i}.png")

        print("[glip infrence...]")
        boxes, logits, phrases = predict(
                                        model=model,
                                        image=image,
                                        caption=TEXT_PROMPT,
                                        box_threshold=BOX_TRESHOLD,
                                        text_threshold=TEXT_TRESHOLD
                                    )
        preds.append({'image_id': i, 'category_id': 2, 
                      'bbox': boxes*image.shape[-1], 
                      'score': logits}
                    )
        annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)
        cv2.imwrite(f"{save_dir}/dino_pred/{i}.png", annotated_frame)
    print('[generating superpoints...]')
    superpoint = gen_superpoint(xyz, rgb, visualize=True, save_dir=save_dir)
    
    print('[converting bbox to 3D segmentation...]')
    sem_seg, ins_seg = bbox2seg(xyz, superpoint, preds, screen_coords, pc_idx, part_names, save_dir, solve_instance_seg=True)
    
    print("[finish!]")
    return preds

# %%
io = IO()
xyz, rgb = normalize_pc("examples/Chair.ply", "examples/zeroshot_Chair", io, "cuda")
img_dir, pc_idx, screen_coords = render_pc(xyz, rgb, "examples/zeroshot_Chair", "cuda")
# Out:
# An exception occurred in telemetry logging.Disabling telemetry to prevent further exceptions.
# Traceback (most recent call last):
#   File "/rhome/kamburoglu/miniconda3/envs/partslip/lib/python3.9/site-packages/iopath/common/file_io.py", line 946, in __log_tmetry_keys
#     handler.log_event()
#   File "/rhome/kamburoglu/miniconda3/envs/partslip/lib/python3.9/site-packages/iopath/common/event_logger.py", line 97, in log_event
#     del self._evt
# AttributeError: _evt
# UserWarning: R is not a valid rotation matrix

# %%
screen_coords[0]
# Out:
# array([[301.90833, 154.62723],
#        [302.001  , 154.86508],
#        [301.68314, 155.22375],
#        ...,
#        [505.16672, 159.29083],
#        [503.9417 , 159.11203],
#        [502.51263, 158.6364 ]], dtype=float32)

# %%
pc_idx.shape
# Out:
# (10, 800, 800)

# %%
np.unique(pc_idx[1])[1:]
# Out:
# array([    71,    118,    121, ..., 301393, 301397, 301400], dtype=int32)

# %%
 model = load_model("../GroundingDINO/groundingdino/config/GroundingDINO_SwinB_cfg.py", "../GroundingDINO/weights/groundingdino_swinb_cogcoor.pth")
# Out:
# final text_encoder_type: bert-base-uncased
# FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
sam_checkpoint = "../SAM/weights/sam_vit_h_4b8939.pth"
model_type = "vit_h"


sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
sam.to(device="cuda")

predictor = SamPredictor(sam)

# %%
metaData = json.load(open("./PartNetE_meta.json"))
metaData
# Out:
# {'Bottle': ['lid'],
#  'Box': ['lid'],
#  'Bucket': ['handle'],
#  'Camera': ['button', 'lens'],
#  'Cart': ['wheel'],
#  'Chair': ['arm', 'back', 'leg', 'seat', 'wheel'],
#  'Clock': ['hand'],
#  'CoffeeMachine': ['button', 'container', 'knob', 'lid'],
#  'Dishwasher': ['door', 'handle'],
#  'Dispenser': ['head', 'lid'],
#  'Display': ['base', 'screen', 'support'],
#  'Door': ['frame', 'door', 'handle'],
#  'Eyeglasses': ['body', 'leg'],
#  'Faucet': ['spout', 'switch'],
#  'FoldingChair': ['seat'],
#  'Globe': ['sphere'],
#  'Kettle': ['lid', 'handle', 'spout'],
#  'Keyboard': ['cord', 'key'],
#  'KitchenPot': ['lid', 'handle'],
#  'Knife': ['blade'],
#  'Lamp': ['base', 'body', 'bulb', 'shade'],
#  'Laptop': ['keyboard', 'screen', 'shaft', 'touchpad', 'camera'],
#  'Lighter': ['lid', 'wheel', 'button'],
#  'Microwave': ['display', 'door', 'handle', 'button'],
#  'Mouse': ['button', 'cord', 'wheel'],
#  'Oven': ['door', 'knob'],
#  'Pen': ['cap', 'button'],
#  'Phone': ['lid', 'button'],
#  'Pliers': ['leg'],
#  'Printer': ['button'],
#  'Refrigerator': ['door', 'handle'],
#  'Remote': ['button'],
#  'Safe': ['door', 'switch', 'button'],
#  'Scissors': ['blade', 'handle', 'screw'],
#  'Stapler': ['body', 'lid'],
#  'StorageFurniture': ['door', 'drawer', 'handle'],
#  'Suitcase': ['handle', 'wheel'],
#  'Switch': ['switch'],
#  'Table': ['door', 'drawer', 'leg', 'tabletop', 'wheel', 'handle'],
#  'Toaster': ['button', 'slider'],
#  'Toilet': ['lid', 'seat', 'button'],
#  'TrashCan': ['footpedal', 'lid', 'door'],
#  'USB': ['cap', 'rotation'],
#  'WashingMachine': ['door', 'button'],
#  'Window': ['window']}

# %%
def toDinoPrompt(metaData,className):
    listOfParts = metaData[className]
    prompt = ""
    partList = {}
    for i,part in enumerate(listOfParts):
        prompt += f"{className} {part}.".lower()
        partList[f"{className} {part}".lower()] = i
    return prompt,partList

# %%
className = "Chair"
TEXT_PROMPT,partList = toDinoPrompt(metaData, className)
BOX_TRESHOLD = 0.2
TEXT_TRESHOLD = 0.3

# %%
preds = []
for i in range(10):
    image_source, image = load_image(f"examples/zeroshot_Chair/rendered_img/{i}.png")
    predictor.set_image(image_source)
    print("[dino infrence...]")
    boxes, logits, phrases = predict(
                                    model=model,
                                    image=image,
                                    caption=TEXT_PROMPT,
                                    box_threshold=BOX_TRESHOLD,
                                    text_threshold=TEXT_TRESHOLD
                                )
    phrases = np.array(phrases)
    
    xyxy = yolobbox2bbox(boxes)*image.shape[-1]

    nms_indexes = nms(torch.tensor(xyxy) , logits, 0.5).numpy()
 
    nms_mask = []
    for t,index in enumerate(nms_indexes):
        if phrases[index].lower() in partList.keys():
            nms_mask.append(t)
    nms_indexes = nms_indexes[nms_mask]
    
    input_boxes = torch.tensor(xyxy[nms_indexes], device=predictor.device)    
    transformed_boxes = predictor.transform.apply_boxes_torch(input_boxes, image_source.shape[:2])
    masks, _, _ = predictor.predict_torch(
        point_coords=None,
        point_labels=None,
        boxes=transformed_boxes,
        multimask_output=False,
    )    

    for index,j in enumerate(nms_indexes):
        preds.append({'image_id': i, 'category_id': phrases[j], 
                      'bbox': boxes[j]*image.shape[-1], 
                      'score': logits[j],
                      'mask':masks[index,0]   
                     }
                    )
    annotated_frame = annotate(image_source=image_source, boxes=boxes[nms_indexes], logits=logits[nms_indexes], phrases=phrases[nms_indexes])
    cv2.imwrite(f"examples/zeroshot_Chair/dino_pred/{i}.png", annotated_frame)
# Out:
# [dino infrence...]
# FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
# UserWarning: None of the inputs have requires_grad=True. Gradients will be None
# [dino infrence...]
# [dino infrence...]
# [dino infrence...]
# [dino infrence...]
# [dino infrence...]
# [dino infrence...]
# [dino infrence...]
# [dino infrence...]
# [dino infrence...]

# %%
preds
# Out:
# [{'image_id': 0,
#   'category_id': 'chair seat',
#   'bbox': tensor([400.7036, 465.8534, 316.9041,  98.0243]),
#   'score': tensor(0.4861),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair wheel',
#   'bbox': tensor([384.7600, 728.8214,  45.7331,  50.1014]),
#   'score': tensor(0.4780),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair arm',
#   'bbox': tensor([260.8008, 390.3780,  55.9765, 113.7317]),
#   'score': tensor(0.4268),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair arm',
#   'bbox': tensor([538.4069, 391.0309,  57.2986, 115.9605]),
#   'score': tensor(0.4161),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair wheel',
#   'bbox': tensor([250.4913, 664.7084,  31.8933,  37.6293]),
#   'score': tensor(0.3782),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair wheel',
#   'bbox': tensor([552.2546, 659.9042,  28.7813,  40.1624]),
#   'score': tensor(0.3685),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair leg',
#   'bbox': tensor([401.2617, 638.4854, 332.4245, 223.3448]),
#   'score': tensor(0.3647),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair wheel',
#   'bbox': tensor([461.8075, 649.7837,  34.9083,  39.6535]),
#   'score': tensor(0.4569),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair arm',
#   'bbox': tensor([367.6588, 381.5738, 195.5217, 108.1498]),
#   'score': tensor(0.4540),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair wheel',
#   'bbox': tensor([275.1451, 680.0952,  44.5861,  45.0805]),
#   'score': tensor(0.4352),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair wheel',
#   'bbox': tensor([456.6608, 573.5802,  31.3969,  30.3855]),
#   'score': tensor(0.3913),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair seat',
#   'bbox': tensor([330.2480, 446.1058, 262.5515, 114.0444]),
#   'score': tensor(0.3909),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair leg',
#   'bbox': tensor([300.6654, 625.4144,  96.7079, 154.2630]),
#   'score': tensor(0.3822),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair wheel',
#   'bbox': tensor([209.5088, 604.6259,  26.8530,  24.2598]),
#   'score': tensor(0.3484),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair leg',
#   'bbox': tensor([338.6955, 608.2908, 285.7842, 186.8255]),
#   'score': tensor(0.3246),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair wheel',
#   'bbox': tensor([478.0569, 637.2481,  38.6479,  39.4135]),
#   'score': tensor(0.4769),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair wheel',
#   'bbox': tensor([309.1126, 634.1338,  39.5724,  37.0514]),
#   'score': tensor(0.4455),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair seat',
#   'bbox': tensor([399.5386, 407.0238, 310.1164, 142.3191]),
#   'score': tensor(0.4183),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair wheel',
#   'bbox': tensor([510.2003, 562.0332,  30.2810,  30.7987]),
#   'score': tensor(0.3908),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair leg',
#   'bbox': tensor([398.4850, 573.4954, 255.0649, 167.9646]),
#   'score': tensor(0.3892),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair wheel',
#   'bbox': tensor([284.7922, 566.9377,  26.2093,  23.4573]),
#   'score': tensor(0.3453),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair arm',
#   'bbox': tensor([257.6766, 397.7042,  27.4844, 116.6715]),
#   'score': tensor(0.3384),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair wheel',
#   'bbox': tensor([529.2743, 677.7681,  44.1154,  43.3073]),
#   'score': tensor(0.4569),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair wheel',
#   'bbox': tensor([595.3574, 610.2939,  28.7588,  34.4753]),
#   'score': tensor(0.4188),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair wheel',
#   'bbox': tensor([331.0128, 643.2549,  35.6728,  37.2675]),
#   'score': tensor(0.3975),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair leg',
#   'bbox': tensor([461.3985, 605.6414, 296.9051, 183.7294]),
#   'score': tensor(0.3643),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair seat',
#   'bbox': tensor([471.7943, 445.8862, 257.9878, 111.6351]),
#   'score': tensor(0.3640),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair leg',
#   'bbox': tensor([380.6790, 596.9960, 134.7581, 128.9113]),
#   'score': tensor(0.3264),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair arm',
#   'bbox': tensor([539.0952, 402.5036,  46.7539, 164.6060]),
#   'score': tensor(0.5124),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair leg',
#   'bbox': tensor([392.3171, 647.3868,  46.1120, 150.0435]),
#   'score': tensor(0.4876),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair arm',
#   'bbox': tensor([262.1019, 402.8871,  46.9760, 164.8808]),
#   'score': tensor(0.4705),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair leg',
#   'bbox': tensor([320.2843, 604.4585, 118.4432,  70.1003]),
#   'score': tensor(0.3923),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair seat',
#   'bbox': tensor([400.7558, 483.4545, 286.5504, 179.3217]),
#   'score': tensor(0.3913),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair leg',
#   'bbox': tensor([482.5171, 601.8462, 117.7268,  66.7264]),
#   'score': tensor(0.3828),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair leg',
#   'bbox': tensor([396.2648, 578.6165,  61.2023, 111.5122]),
#   'score': tensor(0.5217),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair leg',
#   'bbox': tensor([285.8824, 559.4471,  89.9121,  87.5525]),
#   'score': tensor(0.4936),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair arm',
#   'bbox': tensor([391.0054, 313.9095,  39.4650,  52.3366]),
#   'score': tensor(0.4905),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair leg',
#   'bbox': tensor([451.7343, 505.6806,  74.8352,  56.4314]),
#   'score': tensor(0.4182),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair wheel',
#   'bbox': tensor([404.9041, 617.4941,  37.1367,  33.3948]),
#   'score': tensor(0.3880),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair seat',
#   'bbox': tensor([301.5454, 418.2206, 209.0191, 212.5874]),
#   'score': tensor(0.3380),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 6,
#   'category_id': 'chair arm',
#   'bbox': tensor([407.1227, 313.4032,  40.9673,  54.4888]),
#   'score': tensor(0.5971),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 6,
#   'category_id': 'chair leg',
#   'bbox': tensor([399.7072, 576.9173,  71.0832, 103.0188]),
#   'score': tensor(0.5224),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 6,
#   'category_id': 'chair leg',
#   'bbox': tensor([519.8771, 554.6457,  85.3516,  87.4319]),
#   'score': tensor(0.5008),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 6,
#   'category_id': 'chair leg',
#   'bbox': tensor([351.8162, 501.3099,  78.6799,  46.1061]),
#   'score': tensor(0.3271),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 6,
#   'category_id': 'chair seat',
#   'bbox': tensor([496.1637, 394.0553, 205.9002, 162.1348]),
#   'score': tensor(0.3175),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair wheel',
#   'bbox': tensor([514.6397, 630.1613,  30.5225,  42.0327]),
#   'score': tensor(0.5007),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair wheel',
#   'bbox': tensor([163.8493, 628.6065,  36.1859,  45.5009]),
#   'score': tensor(0.4959),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair wheel',
#   'bbox': tensor([231.5137, 632.9397,  38.7489,  36.8974]),
#   'score': tensor(0.4954),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair wheel',
#   'bbox': tensor([418.9316, 634.1474,  36.7114,  34.6552]),
#   'score': tensor(0.4489),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair seat',
#   'bbox': tensor([357.4264, 409.2046, 324.1541, 148.0732]),
#   'score': tensor(0.3972),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair wheel',
#   'bbox': tensor([363.5886, 624.4077,  52.6204,  51.4164]),
#   'score': tensor(0.3909),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair arm',
#   'bbox': tensor([440.7742, 310.6496, 160.4892,  48.6962]),
#   'score': tensor(0.3886),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair arm',
#   'bbox': tensor([438.9873, 347.1628, 157.1865, 122.6372]),
#   'score': tensor(0.3322),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair leg',
#   'bbox': tensor([338.6391, 569.5706, 386.1286, 169.7939]),
#   'score': tensor(0.3180),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair wheel',
#   'bbox': tensor([409.0348, 636.5319,  31.3655,  30.8543]),
#   'score': tensor(0.4573),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair wheel',
#   'bbox': tensor([529.4681, 634.7329,  32.8083,  34.3165]),
#   'score': tensor(0.4270),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair leg',
#   'bbox': tensor([401.7801, 574.4653,  44.0751, 154.4958]),
#   'score': tensor(0.4105),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair seat',
#   'bbox': tensor([399.3900, 410.2909, 292.8771, 176.2297]),
#   'score': tensor(0.4103),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair seat',
#   'bbox': tensor([399.9134, 452.5011, 277.0732,  89.1823]),
#   'score': tensor(0.3458),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair wheel',
#   'bbox': tensor([492.6828, 630.4291,  42.3277,  41.4154]),
#   'score': tensor(0.3249),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair wheel',
#   'bbox': tensor([282.1708, 630.5524,  62.5514,  44.1958]),
#   'score': tensor(0.3218),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair leg',
#   'bbox': tensor([397.9907, 577.3910, 296.8964, 155.6226]),
#   'score': tensor(0.3216),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair wheel',
#   'bbox': tensor([288.3497, 631.8051,  29.8038,  39.5667]),
#   'score': tensor(0.4626),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair wheel',
#   'bbox': tensor([564.4871, 633.4460,  39.4816,  36.1036]),
#   'score': tensor(0.4528),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair wheel',
#   'bbox': tensor([445.2944, 624.8606,  49.5839,  50.0262]),
#   'score': tensor(0.4362),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair wheel',
#   'bbox': tensor([629.3127, 627.5999,  37.3199,  45.6754]),
#   'score': tensor(0.4359),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair wheel',
#   'bbox': tensor([393.7372, 634.2391,  37.6644,  34.8760]),
#   'score': tensor(0.4352),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair seat',
#   'bbox': tensor([443.5341, 409.8475, 323.1489, 146.7927]),
#   'score': tensor(0.4217),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair arm',
#   'bbox': tensor([357.7788, 310.9591, 165.1198,  48.3130]),
#   'score': tensor(0.4086),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair arm',
#   'bbox': tensor([357.9457, 344.5609, 165.1080, 117.6759]),
#   'score': tensor(0.3916),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair leg',
#   'bbox': tensor([460.0327, 597.7106, 376.1602, 111.9863]),
#   'score': tensor(0.3419),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')}]

# %%
pc_aggMask = torch.zeros((301402,len(partList)+1))
pc_aggMask[:,-1]=0.1
for prediction in preds:
    maskedPC_idx = pc_idx[prediction["image_id"],prediction["masks"].cpu().numpy()]
    index_pcMasked = np.unique(maskedPC_idx)[1:]
#     print(prediction["image_id"],index_pcMasked,partList[prediction["category_id"]])
    pc_aggMask[index_pcMasked,partList[prediction["category_id"]]] += prediction["score"]
pc_seg_classes = torch.argmax(pc_aggMask,dim=-1)

# %%
pc_seg_classes.min()
# Out:
# tensor(0)

# %%
xyz.shape
# Out:
# (301402, 3)

# %%
for part in partList:
    rgb_sem = np.zeros((xyz.shape[0], 3))
    rgb_sem[torch.where(pc_seg_classes==partList[part])] = [1,0,0]
    save_colored_pc("examples/zeroshot_Chair/semantic_segDino/%s.ply" % (part), xyz, rgb_sem)

# %%
torch.where(pc_seg_classes==4)
# Out:
# (tensor([ 11903,  11905,  11985,  ..., 294842, 294843, 294844]),)

# %%
partList
# Out:
# {'chair arm': 0,
#  'chair back': 1,
#  'chair leg': 2,
#  'chair seat': 3,
#  'chair wheel': 4}

# %%
preds
# Out:
# [{'image_id': 0,
#   'category_id': 'chair seat',
#   'bbox': tensor([400.7036, 465.8534, 316.9041,  98.0243]),
#   'score': tensor(0.4861),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair wheel',
#   'bbox': tensor([384.7600, 728.8214,  45.7331,  50.1014]),
#   'score': tensor(0.4780),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair arm',
#   'bbox': tensor([260.8008, 390.3780,  55.9765, 113.7317]),
#   'score': tensor(0.4268),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair arm',
#   'bbox': tensor([538.4069, 391.0309,  57.2986, 115.9605]),
#   'score': tensor(0.4161),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair wheel',
#   'bbox': tensor([250.4913, 664.7084,  31.8933,  37.6293]),
#   'score': tensor(0.3782),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair wheel',
#   'bbox': tensor([552.2546, 659.9042,  28.7813,  40.1624]),
#   'score': tensor(0.3685),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 0,
#   'category_id': 'chair leg',
#   'bbox': tensor([401.2617, 638.4854, 332.4245, 223.3448]),
#   'score': tensor(0.3647),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair wheel',
#   'bbox': tensor([461.8075, 649.7837,  34.9083,  39.6535]),
#   'score': tensor(0.4569),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair arm',
#   'bbox': tensor([367.6588, 381.5738, 195.5217, 108.1498]),
#   'score': tensor(0.4540),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair wheel',
#   'bbox': tensor([275.1451, 680.0952,  44.5861,  45.0805]),
#   'score': tensor(0.4352),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair wheel',
#   'bbox': tensor([456.6608, 573.5802,  31.3969,  30.3855]),
#   'score': tensor(0.3913),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair seat',
#   'bbox': tensor([330.2480, 446.1058, 262.5515, 114.0444]),
#   'score': tensor(0.3909),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair leg',
#   'bbox': tensor([300.6654, 625.4144,  96.7079, 154.2630]),
#   'score': tensor(0.3822),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair wheel',
#   'bbox': tensor([209.5088, 604.6259,  26.8530,  24.2598]),
#   'score': tensor(0.3484),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 1,
#   'category_id': 'chair leg',
#   'bbox': tensor([338.6955, 608.2908, 285.7842, 186.8255]),
#   'score': tensor(0.3246),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair wheel',
#   'bbox': tensor([478.0569, 637.2481,  38.6479,  39.4135]),
#   'score': tensor(0.4769),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair wheel',
#   'bbox': tensor([309.1126, 634.1338,  39.5724,  37.0514]),
#   'score': tensor(0.4455),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair seat',
#   'bbox': tensor([399.5386, 407.0238, 310.1164, 142.3191]),
#   'score': tensor(0.4183),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair wheel',
#   'bbox': tensor([510.2003, 562.0332,  30.2810,  30.7987]),
#   'score': tensor(0.3908),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair leg',
#   'bbox': tensor([398.4850, 573.4954, 255.0649, 167.9646]),
#   'score': tensor(0.3892),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair wheel',
#   'bbox': tensor([284.7922, 566.9377,  26.2093,  23.4573]),
#   'score': tensor(0.3453),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 2,
#   'category_id': 'chair arm',
#   'bbox': tensor([257.6766, 397.7042,  27.4844, 116.6715]),
#   'score': tensor(0.3384),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair wheel',
#   'bbox': tensor([529.2743, 677.7681,  44.1154,  43.3073]),
#   'score': tensor(0.4569),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair wheel',
#   'bbox': tensor([595.3574, 610.2939,  28.7588,  34.4753]),
#   'score': tensor(0.4188),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair wheel',
#   'bbox': tensor([331.0128, 643.2549,  35.6728,  37.2675]),
#   'score': tensor(0.3975),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair leg',
#   'bbox': tensor([461.3985, 605.6414, 296.9051, 183.7294]),
#   'score': tensor(0.3643),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair seat',
#   'bbox': tensor([471.7943, 445.8862, 257.9878, 111.6351]),
#   'score': tensor(0.3640),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 3,
#   'category_id': 'chair leg',
#   'bbox': tensor([380.6790, 596.9960, 134.7581, 128.9113]),
#   'score': tensor(0.3264),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair arm',
#   'bbox': tensor([539.0952, 402.5036,  46.7539, 164.6060]),
#   'score': tensor(0.5124),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair leg',
#   'bbox': tensor([392.3171, 647.3868,  46.1120, 150.0435]),
#   'score': tensor(0.4876),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair arm',
#   'bbox': tensor([262.1019, 402.8871,  46.9760, 164.8808]),
#   'score': tensor(0.4705),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair leg',
#   'bbox': tensor([320.2843, 604.4585, 118.4432,  70.1003]),
#   'score': tensor(0.3923),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair seat',
#   'bbox': tensor([400.7558, 483.4545, 286.5504, 179.3217]),
#   'score': tensor(0.3913),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 4,
#   'category_id': 'chair leg',
#   'bbox': tensor([482.5171, 601.8462, 117.7268,  66.7264]),
#   'score': tensor(0.3828),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair leg',
#   'bbox': tensor([396.2648, 578.6165,  61.2023, 111.5122]),
#   'score': tensor(0.5217),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair leg',
#   'bbox': tensor([285.8824, 559.4471,  89.9121,  87.5525]),
#   'score': tensor(0.4936),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair arm',
#   'bbox': tensor([391.0054, 313.9095,  39.4650,  52.3366]),
#   'score': tensor(0.4905),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair leg',
#   'bbox': tensor([451.7343, 505.6806,  74.8352,  56.4314]),
#   'score': tensor(0.4182),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair wheel',
#   'bbox': tensor([404.9041, 617.4941,  37.1367,  33.3948]),
#   'score': tensor(0.3880),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 5,
#   'category_id': 'chair seat',
#   'bbox': tensor([301.5454, 418.2206, 209.0191, 212.5874]),
#   'score': tensor(0.3380),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 6,
#   'category_id': 'chair arm',
#   'bbox': tensor([407.1227, 313.4032,  40.9673,  54.4888]),
#   'score': tensor(0.5971),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 6,
#   'category_id': 'chair leg',
#   'bbox': tensor([399.7072, 576.9173,  71.0832, 103.0188]),
#   'score': tensor(0.5224),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 6,
#   'category_id': 'chair leg',
#   'bbox': tensor([519.8771, 554.6457,  85.3516,  87.4319]),
#   'score': tensor(0.5008),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 6,
#   'category_id': 'chair leg',
#   'bbox': tensor([351.8162, 501.3099,  78.6799,  46.1061]),
#   'score': tensor(0.3271),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 6,
#   'category_id': 'chair seat',
#   'bbox': tensor([496.1637, 394.0553, 205.9002, 162.1348]),
#   'score': tensor(0.3175),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair wheel',
#   'bbox': tensor([514.6397, 630.1613,  30.5225,  42.0327]),
#   'score': tensor(0.5007),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair wheel',
#   'bbox': tensor([163.8493, 628.6065,  36.1859,  45.5009]),
#   'score': tensor(0.4959),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair wheel',
#   'bbox': tensor([231.5137, 632.9397,  38.7489,  36.8974]),
#   'score': tensor(0.4954),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair wheel',
#   'bbox': tensor([418.9316, 634.1474,  36.7114,  34.6552]),
#   'score': tensor(0.4489),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair seat',
#   'bbox': tensor([357.4264, 409.2046, 324.1541, 148.0732]),
#   'score': tensor(0.3972),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair wheel',
#   'bbox': tensor([363.5886, 624.4077,  52.6204,  51.4164]),
#   'score': tensor(0.3909),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair arm',
#   'bbox': tensor([440.7742, 310.6496, 160.4892,  48.6962]),
#   'score': tensor(0.3886),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair arm',
#   'bbox': tensor([438.9873, 347.1628, 157.1865, 122.6372]),
#   'score': tensor(0.3322),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 7,
#   'category_id': 'chair leg',
#   'bbox': tensor([338.6391, 569.5706, 386.1286, 169.7939]),
#   'score': tensor(0.3180),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair wheel',
#   'bbox': tensor([409.0348, 636.5319,  31.3655,  30.8543]),
#   'score': tensor(0.4573),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair wheel',
#   'bbox': tensor([529.4681, 634.7329,  32.8083,  34.3165]),
#   'score': tensor(0.4270),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair leg',
#   'bbox': tensor([401.7801, 574.4653,  44.0751, 154.4958]),
#   'score': tensor(0.4105),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair seat',
#   'bbox': tensor([399.3900, 410.2909, 292.8771, 176.2297]),
#   'score': tensor(0.4103),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair seat',
#   'bbox': tensor([399.9134, 452.5011, 277.0732,  89.1823]),
#   'score': tensor(0.3458),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair wheel',
#   'bbox': tensor([492.6828, 630.4291,  42.3277,  41.4154]),
#   'score': tensor(0.3249),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair wheel',
#   'bbox': tensor([282.1708, 630.5524,  62.5514,  44.1958]),
#   'score': tensor(0.3218),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 8,
#   'category_id': 'chair leg',
#   'bbox': tensor([397.9907, 577.3910, 296.8964, 155.6226]),
#   'score': tensor(0.3216),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair wheel',
#   'bbox': tensor([288.3497, 631.8051,  29.8038,  39.5667]),
#   'score': tensor(0.4626),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair wheel',
#   'bbox': tensor([564.4871, 633.4460,  39.4816,  36.1036]),
#   'score': tensor(0.4528),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair wheel',
#   'bbox': tensor([445.2944, 624.8606,  49.5839,  50.0262]),
#   'score': tensor(0.4362),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair wheel',
#   'bbox': tensor([629.3127, 627.5999,  37.3199,  45.6754]),
#   'score': tensor(0.4359),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair wheel',
#   'bbox': tensor([393.7372, 634.2391,  37.6644,  34.8760]),
#   'score': tensor(0.4352),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair seat',
#   'bbox': tensor([443.5341, 409.8475, 323.1489, 146.7927]),
#   'score': tensor(0.4217),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair arm',
#   'bbox': tensor([357.7788, 310.9591, 165.1198,  48.3130]),
#   'score': tensor(0.4086),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair arm',
#   'bbox': tensor([357.9457, 344.5609, 165.1080, 117.6759]),
#   'score': tensor(0.3916),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')},
#  {'image_id': 9,
#   'category_id': 'chair leg',
#   'bbox': tensor([460.0327, 597.7106, 376.1602, 111.9863]),
#   'score': tensor(0.3419),
#   'masks': tensor([[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]], device='cuda:0')}]
